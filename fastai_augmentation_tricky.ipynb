# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup-&amp;-Summary" data-toc-modified-id="Setup-&amp;-Summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup &amp; Summary</a></span><ul class="toc-item"><li><span><a href="#Workflow" data-toc-modified-id="Workflow-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Workflow</a></span></li><li><span><a href="#Reference:" data-toc-modified-id="Reference:-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Reference:</a></span></li><li><span><a href="#Setup-my-kaggle-API" data-toc-modified-id="Setup-my-kaggle-API-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Setup my kaggle API</a></span></li><li><span><a href="#Import-everything" data-toc-modified-id="Import-everything-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Import everything</a></span></li></ul></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Read-CSV-data" data-toc-modified-id="Read-CSV-data-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Read CSV data</a></span></li><li><span><a href="#Image-array-to-images" data-toc-modified-id="Image-array-to-images-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>Image array to images</a></span></li><li><span><a href="#Make-Data-bunch" data-toc-modified-id="Make-Data-bunch-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>Make Data bunch</a></span></li></ul></li></ul></li><li><span><a href="#Data-Augmentation-with-Fastai-API" data-toc-modified-id="Data-Augmentation-with-Fastai-API-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Augmentation with Fastai API</a></span></li><li><span><a href="#Train-Model" data-toc-modified-id="Train-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train Model</a></span></li><li><span><a href="#Fine-tune-model" data-toc-modified-id="Fine-tune-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Fine tune model</a></span></li><li><span><a href="#Make-predictions" data-toc-modified-id="Make-predictions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Make predictions</a></span></li></ul></div>

# %% [markdown]
# # Setup & Summary

# %% [markdown]
# ## Workflow
#
# - data preparation: transfer df to images, the format that fastai can load
# - fastai:
#     - augmentation, learning rate finder, 30 epochs training

# %% [markdown]
# ## Reference:
# - https://www.kaggle.com/nitron/facial-keypoints-fastai-image-regression

# %% [markdown]
# ## Setup my kaggle API

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ['KAGGLE_USERNAME'] = "xxx"
os.environ['KAGGLE_KEY'] = "xxx"

# %% [markdown]
# ## Import everything

# %%
import numpy as np 
import pandas as pd

from fastai.vision import *
from fastai import *

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import shutil
import torch

rn_seed=1
np.random.seed(rn_seed)

# %% [markdown]
# # Load Data

# %% [markdown]
# Control Variables

# %%
train_path = Path('./data/fastai_train')
test_path = Path('./data/fastai_test')

# %% [markdown]
# ### Read CSV data

# %%
root = Path('./data')

# %%
len(pd.read_csv(root/'training.csv'))
# Out:
# 7049

# %%
id_lookup = pd.read_csv(root/'IdLookupTable.csv')
train_csv = pd.read_csv(root/'training.csv')
test_csv = pd.read_csv(root/'test.csv')

# %%
id_lookup.head()
# Out:
#    RowId  ImageId              FeatureName  Location
# 0      1        1        left_eye_center_x       NaN
# 1      2        1        left_eye_center_y       NaN
# 2      3        1       right_eye_center_x       NaN
# 3      4        1       right_eye_center_y       NaN
# 4      5        1  left_eye_inner_corner_x       NaN

# %%
for c in train_csv.columns:
    if(train_csv[c].dtype!='object'):
        train_csv[c]=train_csv[c].fillna(train_csv[c].median())

# %%
len(train_csv)
# Out:
# 7049

# %%
train_csv.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        7049.000000        7049.000000         7049.000000
# mean           66.359218          37.651059           30.306001
# std             3.445790           3.150692            3.080386
# min            22.763345           1.616512            0.686592
# 25%            65.084235          35.906648           28.788000
# 50%            66.497566          37.528055           30.251378
# 75%            68.024349          39.254400           31.767416
# max            94.689280          80.502649           85.039381
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         7049.000000              7049.000000              7049.000000
# mean            37.976641                59.257811                37.899533
# std              3.030830                 1.528334                 1.309824
# min              4.091264                19.064954                27.190098
# 25%             36.329459                59.304615                37.878040
# 50%             37.813273                59.304615                37.878040
# 75%             39.562527                59.304615                37.878040
# max             81.270911                84.440991                66.562559
#
#        left_eye_outer_corner_x  left_eye_outer_corner_y  \
# count              7049.000000              7049.000000
# mean                 73.274406                37.660882
# std                   1.931566                 1.634136
# min                  27.571879                26.250023
# 25%                  73.247824                37.639015
# 50%                  73.247824                37.639015
# 75%                  73.247824                37.639015
# max                  95.258090                64.618230
#
#        right_eye_inner_corner_x  right_eye_inner_corner_y  ...   nose_tip_x  \
# count               7049.000000               7049.000000  ...  7049.000000
# mean                  36.651898                 37.958820  ...    48.374186
# std                    1.332939                  1.311357  ...     4.280038
# min                    5.751046                 26.250023  ...    12.944699
# 25%                   36.651562                 37.944075  ...    46.602370
# 50%                   36.651562                 37.944075  ...    48.424713
# 75%                   36.651562                 37.944075  ...    50.330437
# max                   70.714966                 69.808803  ...    89.438592
#
#         nose_tip_y  mouth_left_corner_x  mouth_left_corner_y  \
# count  7049.000000          7049.000000          7049.000000
# mean     62.715884            63.212873            75.840500
# std       5.720567             2.314468             2.599481
# min      17.932414            22.923362            57.023258
# 25%      59.292697            63.178286            75.778689
# 50%      63.451421            63.178286            75.778689
# 75%      66.492686            63.178286            75.778689
# max      95.935644            84.767123            94.673637
#
#        mouth_right_corner_x  mouth_right_corner_y  mouth_center_top_lip_x  \
# count           7049.000000           7049.000000             7049.000000
# mean              32.955930             76.058293               47.928057
# std                2.249786              2.508036                1.887842
# min                2.245766             56.690208               12.605173
# 25%               32.982305             76.000592               47.905490
# 50%               32.982305             76.000592               47.905490
# 75%               32.982305             76.000592               47.905490
# max               74.017993             95.510678               83.989082
#
#        mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# count             7049.000000                7049.000000
# mean                72.706601                  48.569592
# std                  2.970112                   4.259953
# min                 56.719043                  12.536477
# 25%                 72.605173                  46.584000
# 50%                 72.605173                  48.594978
# 75%                 72.605173                  50.662249
# max                 94.548359                  89.438592
#
#        mouth_center_bottom_lip_y
# count                7049.000000
# mean                   78.968864
# std                     5.395201
# min                    25.850503
# 25%                    75.567671
# 50%                    78.696326
# 75%                    82.222604
# max                    95.808983
#
# [8 rows x 30 columns]

# %%
test_csv.head()
# Out:
#    ImageId                                              Image
# 0        1  182 183 182 182 180 180 176 169 156 137 124 10...
# 1        2  76 87 81 72 65 59 64 76 69 42 31 38 49 58 58 4...
# 2        3  177 176 174 170 169 169 168 166 166 166 161 14...
# 3        4  176 174 174 175 174 174 176 176 175 171 165 15...
# 4        5  50 47 44 101 144 149 120 58 48 42 35 35 37 39 ...

# %% [markdown]
# ### Image array to images

# %% [markdown]
# Save train images

# %%
def save_str_img(strimg,w,h,flpath):
    px=255-np.array(strimg.split(),dtype=int)
    if(len(px)==w*h and len(px)%w==0 and len(px)%h==0):
        cpx = list(px.reshape(w,h))
        img = Image(Tensor([cpx,cpx,cpx]))
        img.save(flpath)
        return img
    else:
        raise Exception("Invalid height and width")

# %%
# make image folders
# shutil.rmtree(train_path)
train_path.mkdir(exist_ok=True)
test_path.mkdir(exist_ok=True)

# %% [markdown]
# - only save data for one time
# - mute afterwards

# %%
# for index, train_row in train_csv.iterrows():
#     save_str_img(train_row.Image,96,96,train_path/(str(index)+'.jpg'))

# for index, test_row in test_csv.iterrows():
#     save_str_img(test_row.Image,96,96,test_path/(str(index)+'.jpg'))

# %% [markdown]
# ### Make Data bunch

# %%
def get_locs(flname):
    index = int(flname.name[:-4])
    plist=[]
    coords=list(train_csv.loc[index])
    for i in range(len(coords)//2):
        plist.append([coords[i*2+1],coords[i*2]])
    return tensor(plist)

# %%
# make points image data bunch
data = (PointsItemList.from_folder(train_path)
        .split_by_rand_pct(0.05,seed=rn_seed)
        .label_from_func(get_locs)
        .transform([],size=(96,96))
        .databunch(num_workers=0)
       )

# %%
data.show_batch(3,figsize=(6,6))

# %%
## flip
class RandomHorizontalFlip(object):
    '''
    Convert ndarrays in sample to Tensors.
    '''
    
    def __init__(self, p=0.5, dataset='A'):
        
        '''
        Args:
        p (float): probability of the image being flipped,
                   defalut value = 0.5
        dataset (string): A=All, L=dataset L, S=dataset S,
                   default value =  A
        '''
        self.p = p
        self.dataset = dataset

    def __call__(self, sample):
        
        if self.dataset == 'L':
            flip_indices = [(0, 2), (1, 3)]
        elif self.dataset == 'S':
            flip_indices = [(0, 4), (1, 5), (2, 6), (3, 7),
                            (8, 12), (9, 13), (10, 14), (11, 15),
                            (16, 18), (17, 19)]
        else:
            flip_indices = [(0, 2), (1, 3),
                            (4, 8), (5, 9), (6, 10), (7, 11),
                            (12, 16), (13, 17), (14, 18), (15, 19),
                            (22, 24), (23, 25)]
        
        image, keypoints = sample['image'], sample['keypoints']
        
        if np.random.random() < self.p:
            image = image[:, ::-1]
            if keypoints is not None:
                for a, b in flip_indices:
                    keypoints[a], keypoints[b]= keypoints[b], keypoints[a]
                keypoints[::2] = 96. - keypoints[::2]
        
        return {'image': image, 
                'keypoints': keypoints}

# %%
class Normalize(object):
    '''Normalize input images'''
    
    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']
        
        return {'image': image / 255., # scale to [0, 1]
                'keypoints': keypoints}
        
class ToTensor(object):
    '''Convert ndarrays in sample to Tensors.'''

    def __call__(self, sample):
        image, keypoints = sample['image'], sample['keypoints']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.reshape(1, IMG_SIZE, IMG_SIZE)
        image = torch.from_numpy(image)
        
        if keypoints is not None:
            keypoints = torch.from_numpy(keypoints)
            return {'image': image, 'keypoints': keypoints}
        else:
            return {'image': image}

# %% [markdown]
# # Data Augmentation with Fastai API

# %%
from torchvision import transforms, utils

# %%
L_aug_tfms = transforms.Compose([RandomHorizontalFlip(p=0.5, dataset='L'),
                                 Normalize(), ToTensor()])

# %%
L_aug_tfms
# Out:
# Compose(
#     <__main__.RandomHorizontalFlip object at 0x7f8fb03f1190>
#     <__main__.Normalize object at 0x7f8fb03f11d0>
#     <__main__.ToTensor object at 0x7f8fb03f1210>
# )

# %%
tfms = get_transforms(do_flip=True, flip_vert=False, max_rotate=10
               , max_zoom=1, max_lighting=None, max_warp=None
               , p_affine=0, p_lighting=0, xtra_tfms=None)

data_aug = (PointsItemList.from_folder(train_path)
        .split_by_rand_pct(0.05,seed=rn_seed)
        .label_from_func(get_locs)
        .transform(L_aug_tfms,tfm_y=True,size=(96,96))
        .databunch(num_workers=0)
       )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-e4ea1b16e542> in <module>
#       6         .split_by_rand_pct(0.05,seed=rn_seed)
#       7         .label_from_func(get_locs)
# ----> 8         .transform(L_aug_tfms,tfm_y=True,size=(96,96))
#       9         .databunch(num_workers=0)
#      10        )
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/data_block.py in transform(self, tfms, **kwargs)
#     502         "Set `tfms` to be applied to the xs of the train and validation set."
#     503         if not tfms: tfms=(None,None)
# --> 504         assert is_listy(tfms) and len(tfms) == 2, "Please pass a list of two lists of transforms (train and valid)."
#     505         self.train.transform(tfms[0], **kwargs)
#     506         self.valid.transform(tfms[1], **kwargs)
#
# AssertionError: Please pass a list of two lists of transforms (train and valid).

# %%
def _plot_aug(i,j,ax):
    x,y = data_aug.train_ds[2]
    x.show(ax, y=y)

plot_multi(_plot_aug, 3, 3, figsize=(8,6))

# %% [markdown]
# # Train Model

# %%
data = data_aug

# %%
# calculates distance between true and predictions
def mloss(y_true, y_pred):
    y_true=y_true.view(-1,15,2)
    
    y_true[:,:,0]=y_true[:,:,0].clone()-y_pred[:,:,0]
    y_true[:,:,1]=y_true[:,:,1].clone()-y_pred[:,:,1]
    
    y_true[:,:,0]=y_true[:,:,0].clone()**2
    y_true[:,:,1]=y_true[:,:,1].clone()**2
    
    return y_true.sum(dim=2).sum(dim=1).sum()

# %%
learn = cnn_learner(data,models.resnet152,loss_func=mloss)

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5225.102051</td>
#       <td>1120.768799</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2178.013916</td>
#       <td>304.081696</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>634.018188</td>
#       <td>148.917862</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>240.847977</td>
#       <td>169.513748</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>171.918762</td>
#       <td>124.822624</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>157.401276</td>
#       <td>135.751266</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>150.983337</td>
#       <td>126.557808</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>141.845444</td>
#       <td>124.657646</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>133.394531</td>
#       <td>124.171257</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>129.516083</td>
#       <td>127.707977</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(rows=3,figsize=(6,6))

# %%
learn.save('s1_aug')

# %% [markdown]
# # Fine tune model

# %%
learn.load('s1_aug');

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='72' class='' max='104', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       69.23% [72/104 00:30<00:13 425.1565]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(30,1e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>124.146263</td>
#       <td>121.019264</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>113.225815</td>
#       <td>109.667534</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>99.839340</td>
#       <td>113.814095</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>90.508682</td>
#       <td>131.587418</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>82.839851</td>
#       <td>120.915230</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>78.401222</td>
#       <td>106.121094</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>72.929199</td>
#       <td>100.210381</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>66.198753</td>
#       <td>84.083946</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>63.542683</td>
#       <td>148.752426</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>54.991455</td>
#       <td>147.202408</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>50.408001</td>
#       <td>155.626038</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>44.075016</td>
#       <td>102.184128</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>37.512142</td>
#       <td>74.063622</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>32.375584</td>
#       <td>178.862656</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>31.073263</td>
#       <td>90.405266</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>25.655994</td>
#       <td>154.207092</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>22.934261</td>
#       <td>102.704826</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>20.376289</td>
#       <td>115.689995</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>16.860138</td>
#       <td>110.945137</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>15.246624</td>
#       <td>100.859589</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>13.702618</td>
#       <td>94.485504</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>11.726300</td>
#       <td>113.047043</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>10.317789</td>
#       <td>122.470970</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>10.313703</td>
#       <td>110.124214</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>8.066232</td>
#       <td>111.954399</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7.587775</td>
#       <td>125.971756</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>8.164679</td>
#       <td>112.084251</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>7.118684</td>
#       <td>96.838432</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>6.964394</td>
#       <td>104.535034</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>7.697987</td>
#       <td>98.058304</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(rows=3,figsize=(6,6))

# %% [markdown]
# # Make predictions

# %% [markdown]
# Predict and display in one image

# %%
def flp(npa):
    for i in range(npa.shape[0]):
        if(i%2==1):
            tmp=npa[i]
            npa[i]=npa[i-1]
            npa[i-1]=tmp
    return npa

# %%
def get_coords(imgpnts):
    return ((imgpnts+1)*48).numpy()

# %%
test_img = open_image(test_path/'1600.jpg')
pred = learn.predict(test_img)
test_img.show(y=pred[0])

# %%
test_img = open_image(test_path/'1600.jpg')
pred = learn.predict(test_img)
test_img.show(y=ImagePoints(FlowField(test_img.size,torch.from_numpy(get_coords(pred[1])))))

# %% [markdown]
# Make predictions and save dataframe

# %%
a=list(train_csv.columns.values)
a.remove('Image')
a.append('ImageId')

# %%
test_preds = pd.DataFrame(columns=a)

# %%
from ipywidgets import IntProgress
from IPython.display import display

f = IntProgress(min=0, max=test_csv.count()[0]) # instantiate the bar
display(f)
for test_index in range(test_csv.count()[0]):
    timg = open_image(test_path/(str(test_index)+'.jpg'))
    pred = learn.predict(timg)
    a=np.abs(flp(get_coords(pred[1]).reshape(1,-1)[0]))
    a=np.append(a,test_csv.loc[test_index].ImageId)
    test_preds.loc[test_index]=a
    f.value+=1
# Out:
# IntProgress(value=0, max=1783)

# %%
test_preds.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        1783.000000        1783.000000         1783.000000
# mean           56.981818          37.635656           39.386041
# std            13.016023           1.157347           12.497083
# min            28.130718          33.141964           27.590755
# 25%            48.319780          36.940878           30.850382
# 50%            64.661484          37.764725           32.049698
# 75%            65.970669          38.425549           47.755079
# max            69.343147          43.257080           66.997803
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         1783.000000              1783.000000              1783.000000
# mean            38.097266                53.478336                37.910093
# std              1.250449                 7.937799                 0.515921
# min             33.118900                36.573193                35.461250
# 25%             37.359713                48.188766                37.712671
# 50%             38.256557                58.297684                37.919926
# 75%             38.935877                58.927128                38.123091
# max             41.335655                60.815430                41.479347
#
#        left_eye_outer_corner_x  left_eye_outer_corner_y  \
# count              1783.000000              1783.000000
# mean                 60.244074                37.647440
# std                  17.819279                 0.594933
# min                  21.591116                35.411407
# 25%                  48.573425                37.351761
# 50%                  71.165314                37.629726
# 75%                  72.437065                37.887869
# max                  75.428780                42.852905
#
#        right_eye_inner_corner_x  right_eye_inner_corner_y  ...   nose_tip_y  \
# count               1783.000000               1783.000000  ...  1783.000000
# mean                  42.468231                 38.002247  ...    62.736126
# std                    7.984297                  0.502836  ...     3.992895
# min                   35.388252                 35.387585  ...    41.463463
# 25%                   36.975895                 37.811928  ...    61.198200
# 50%                   37.506649                 38.051067  ...    63.664406
# 75%                   47.812557                 38.261808  ...    65.330338
# max                   59.304955                 39.704601  ...    72.335632
#
#        mouth_left_corner_x  mouth_left_corner_y  mouth_right_corner_x  \
# count          1783.000000          1783.000000           1783.000000
# mean             55.390768            75.780471             40.712356
# std              10.792413             1.599262             10.563553
# min              30.841244            69.547470             30.615744
# 25%              48.507038            75.044930             33.428978
# 50%              61.759125            75.627419             34.421555
# 75%              62.828012            76.403648             47.486387
# max              65.515755            87.403717             64.592926
#
#        mouth_right_corner_y  mouth_center_top_lip_x  mouth_center_top_lip_y  \
# count           1783.000000             1783.000000             1783.000000
# mean              76.021527               47.966022               72.717959
# std                1.576945                0.637717                1.917596
# min               68.826096               44.979721               63.390030
# 25%               75.356121               47.593460               72.058830
# 50%               75.934036               47.961632               72.766006
# 75%               76.651283               48.319502               73.655266
# max               85.945671               50.516441               82.007385
#
#        mouth_center_bottom_lip_x  mouth_center_bottom_lip_y      ImageId
# count                1783.000000                1783.000000  1783.000000
# mean                   48.352674                  78.665167   892.000000
# std                     2.566401                   3.606420   514.852082
# min                    36.868511                  68.656929     1.000000
# 25%                    46.902290                  76.183495   446.500000
# 50%                    48.429749                  78.199944   892.000000
# 75%                    49.932755                  80.717819  1337.500000
# max                    56.923519                  99.712738  1783.000000
#
# [8 rows x 31 columns]

# %%
test_preds.ImageId=test_preds.ImageId.astype('int')
test_preds.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          63.336205          37.107044           33.712666
# 1          66.553696          37.533752           29.434593
# 2          65.543396          35.884403           31.723269
# 3          65.983398          37.282902           30.897018
# 4          67.230911          37.109932           29.772177
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.243027                57.499065                37.621750
# 1           37.288887                59.196136                38.378922
# 2           37.855396                59.082150                37.224953
# 3           40.841957                58.952671                38.252323
# 4           37.361568                60.161873                37.682472
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                68.289803                37.900627                 38.683289
# 1                72.839638                38.409470                 36.304928
# 2                71.280838                36.835869                 37.300724
# 3                71.878448                37.896362                 37.211922
# 4                73.426331                37.942047                 36.211357
#
#    right_eye_inner_corner_y  ...  nose_tip_y  mouth_left_corner_x  \
# 0                 37.456406  ...   50.088215            60.017075
# 1                 38.111847  ...   59.891041            62.299088
# 2                 37.711727  ...   56.949417            62.875313
# 3                 38.997242  ...   59.596306            63.986355
# 4                 37.569313  ...   57.669243            63.082710
#
#    mouth_left_corner_y  mouth_right_corner_x  mouth_right_corner_y  \
# 0            74.968605             36.206772             75.000633
# 1            78.229645             33.012436             78.209373
# 2            74.311142             35.512276             75.052704
# 3            76.247726             35.191597             77.529572
# 4            76.448471             33.501122             76.314346
#
#    mouth_center_top_lip_x  mouth_center_top_lip_y  mouth_center_bottom_lip_x  \
# 0               48.020752               68.376892                  48.335205
# 1               47.329948               74.233780                  47.213684
# 2               49.149506               70.731598                  51.036358
# 3               49.327499               71.851044                  53.411392
# 4               48.399940               71.671822                  49.958530
#
#    mouth_center_bottom_lip_y  ImageId
# 0                  83.011124        1
# 1                  86.235985        2
# 2                  80.707886        3
# 3                  79.982628        4
# 4                  84.447006        5
#
# [5 rows x 31 columns]

# %%
sub = pd.DataFrame(columns=['RowId','Location'])
for index,row in id_lookup.iterrows():
    fname = row.FeatureName
    trow=test_preds.loc[test_preds['ImageId']==row.ImageId]
    sub.loc[index]=[row.RowId,trow.iloc[0][fname]]

# %%
sub.RowId=sub.RowId.astype('int')
sub.head()
# Out:
#    RowId   Location
# 0      1  63.336205
# 1      2  37.107044
# 2      3  33.712666
# 3      4  36.243027
# 4      5  57.499065

# %%
sub.Location.max()
# Out:
# 99.71273803710938

# %%
sub.Location = np.where(sub.Location<96, sub.Location, 96)

# %%
sub.to_csv("./data/sub_fastai_aug.csv",index=False)

# %%
# !kaggle competitions submit -c facial-keypoints-detection -f data/sub_fastai_aug.csv -m "fastai aug"
# Out:
# 100%|█████████████████████████████████████████| 629k/629k [00:02<00:00, 274kB/s]
# Successfully submitted to Facial Keypoints Detection
